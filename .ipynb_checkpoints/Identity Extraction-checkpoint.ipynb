# %%
# !pip install onnxruntime

# %%
import os, time
import insightface, torch, onnxruntime, cv2
import numpy as np
from insightface.app.common import Face
from PIL import Image
import requests
import torch
import torchvision
import matplotlib.pyplot as plt
from modules.controlnet import IdentityFilter, BaseFilter
from train_c_controlnet import WurstCore
import time
import yaml

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# SETUP WARPCORE
config_file = 'configs/controlnet_c_3b_identity.yml'
with open(config_file, "r", encoding="utf-8") as file:
    loaded_config = yaml.safe_load(file)
    loaded_config['use_fsdp'] = False
    loaded_config['batch_size'] = 4
    
    # Humans 7M
    loaded_config['captions_getter']  = ['combined_txt', 'identity']
    loaded_config['webdataset_path'] = 'pipe:aws s3 cp s3://laion-west/humans-7M-with-blip-caps+aesthetics+nsfw/00000{1..5499}.tar -'

warpcore = WurstCore(
    config_dict=loaded_config,
    device=device
)
# Out:
# >>> RESUMING TRAINING FROM ITER  1

# %%
extras = warpcore.setup_extras_pre()
data = warpcore.setup_data(extras)
# Out:
# 2024-01-21 01:05:51.333968931 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242910, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:51.333972104 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242911, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:51.334006134 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242912, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:51.335038707 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242934, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:51.335096383 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242935, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:51.335133647 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242936, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# 2024-01-21 01:05:52.208671637 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242957, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.208728925 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242958, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.208763902 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242959, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.209983420 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242981, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.210004628 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242982, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.210043034 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3242983, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.250544805 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243004, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.250566518 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243005, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.250587547 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243006, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.251691100 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243028, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.251725665 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243029, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.251762319 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243030, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.322600616 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243051, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.322637530 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243052, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.322677022 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243053, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.323821118 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243075, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.323864233 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243076, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.323898973 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243077, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.352444134 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243098, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# 2024-01-21 01:05:52.352469092 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243099, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.352489297 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243100, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.353761973 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243122, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.353772122 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243123, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:05:52.353826430 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3243124, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (320, 320)
# Training with batch size 4 (4/GPU)

# %%
controlnet_filter = IdentityFilter(device, max_faces=4, p_drop=0.0, p_full=0.0) # , p_drop=0.05, p_full=0.5)
# Out:
# 2024-01-21 01:16:15.851585903 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249013, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:15.851598645 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249037, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:15.851606656 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249012, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:15.851592266 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249011, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:15.851600582 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249036, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:15.851598964 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249035, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# 2024-01-21 01:16:17.121531361 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249058, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.121558375 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249059, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.121593140 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249060, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.123011357 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249082, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.123066962 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249083, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.123102673 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249084, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.181250793 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249105, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.181352514 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249106, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.181425307 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249107, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.182610954 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249129, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.182682718 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249130, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.182722677 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249131, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.291847010 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249152, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.291876996 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249153, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.291912591 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249154, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.292732962 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249176, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.292758260 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249177, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.292795974 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249178, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.321715742 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249199, index: 20, mask: {21, 69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# Applied providers: ['AzureExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'AzureExecutionProvider': {}}
# 2024-01-21 01:16:17.321739510 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249200, index: 21, mask: {22, 70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.321778647 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249201, index: 22, mask: {23, 71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.322558289 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249223, index: 44, mask: {45, 93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.322595249 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249224, index: 45, mask: {46, 94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2024-01-21 01:16:17.322660473 [E:onnxruntime:Default, env.cc:254 ThreadMain] pthread_setaffinity_np failed for thread: 3249225, index: 46, mask: {47, 95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# find model: ./modules/cnet_modules/face_id/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (320, 320)

# %%
# urls = [
#     "https://cdn.discordapp.com/attachments/1198177251238363219/1198309860756963468/brad-pitt-attends-the-premiere-of-20th-century-foxs--square.jpg?ex=65be7006&is=65abfb06&hm=2c9632a1d37ad9e776dad0db96966ade519e25ad6c7dde00793b01af0f0836f6&", # BRAD PITT
#     "https://static.ffx.io/images/$zoom_1.444%2C$multiply_0.7725%2C$ratio_1.5%2C$width_756%2C$x_70%2C$y_0/t_crop_custom/q_86%2Cf_auto/6ca4ae8917e05b81290f3b20b984f93d11e2ddc6", # FAMOUS PEOPLE
#     "https://res.cloudinary.com/ybmedia/image/upload/c_crop,h_1123,w_2000,x_0,y_0/c_fill,f_auto,h_1215,q_auto,w_2160/v1/m/4/b/4b4e8a03ce096567ccf8f2a9283c224f85fe6f89/famous-foursomes-pop-culture.jpg",
# #     "https://qph.cf2.quoracdn.net/main-qimg-d0861bad092a1512204d64615e2c66bb-pjlq",
#     "https://cdn.discordapp.com/attachments/1039261364935462942/1198425943404986578/5cc9adc10b83cd4e275bf2b69207e665.png?ex=65bedc22&is=65ac6722&hm=97f89e7bc1112fd080ce1400908bb47ce6e3fc4d05a84b6c5716a60146f1c461&",
# ]
# images = torch.stack([extras.transforms(Image.open(requests.get(url, stream=True).raw).convert("RGB")) for url in urls], dim=0).to(device)
images = next(data.iterator)['images']
# images = images.flip(dims=[-1])

plt.figure(figsize=(24, 24))
plt.axis("off")
plt.imshow(torch.cat([
    torch.cat([i for i in images.clamp(0, 1)], dim=-1),
], dim=-2).permute(1, 2, 0).cpu())
plt.show()

# %%
start_time = time.time()
cnet_input, cnet_input_preview = controlnet_filter(images)
print("ELAPSED:", f"{round(time.time()-start_time, 2)}s")
    
plt.figure(figsize=(24, 24))
plt.axis("off")
plt.imshow(torch.cat([
    torch.cat([i for i in images.cpu().clamp(0, 1)], dim=-1),
    torch.cat([i for i in cnet_input_preview.cpu().clamp(0, 1)], dim=-1),
], dim=-2).permute(1, 2, 0).cpu())
plt.show()

plt.figure(figsize=(24, 24))
plt.axis("off")
plt.imshow(torch.cat([
    torch.cat([i for i in cnet_input[:, :3].cpu().clamp(0, 1)], dim=-1),
], dim=-2).permute(1, 2, 0).cpu())
plt.show()
# Out:
# ELAPSED: 0.82s
